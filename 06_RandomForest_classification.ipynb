# %%
import zipfile

zip_path = "/content/human_activity.zip"

with zipfile.ZipFile(zip_path, "r") as z:
    print(z.namelist()[:30])
# Out:
# ['UCI HAR Dataset.names', 'UCI HAR Dataset.zip']

# %%
with zipfile.ZipFile("/content/human_activity.zip", "r") as z:
    z.extract("UCI HAR Dataset.zip", "/content/")

# %%
with zipfile.ZipFile("/content/UCI HAR Dataset.zip", "r") as z:
    z.extractall("/content/")

# %%
import pandas as pd

x = pd.read_csv(
    "/content/UCI HAR Dataset/train/X_train.txt",
    sep=r"\s+",
    header=None
)

y = pd.read_csv(
    "/content/UCI HAR Dataset/train/y_train.txt",
    sep=r"\s+",
    header=None
)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test , y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=45)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
rf = RandomForestClassifier()

# %%
rf.fit(x_train , y_train)
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier()

# %%
y_pred = rf.predict(x_test)

# %%
rf.score(x_test, y_test)
# Out:
# 0.981645139360979

# %%
cm = confusion_matrix(y_test , y_pred)
print(cm)
# Out:
# [[249   1   3   0   0   0]
#  [  0 231   2   0   0   0]
#  [  0   1 207   0   0   0]
#  [  0   0   0 220  11   0]
#  [  0   0   0   8 234   0]
#  [  0   0   0   1   0 303]]

# %%
cr = classification_report(y_test, y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      0.98      0.99       253
#            2       0.99      0.99      0.99       233
#            3       0.98      1.00      0.99       208
#            4       0.96      0.95      0.96       231
#            5       0.96      0.97      0.96       242
#            6       1.00      1.00      1.00       304
#
#     accuracy                           0.98      1471
#    macro avg       0.98      0.98      0.98      1471
# weighted avg       0.98      0.98      0.98      1471

# %%
features = pd.read_csv(
    "/content/UCI HAR Dataset/features.txt",
    sep=r"\s+",
    header=None
)

# %%
x_train.columns = features[1]
x_test.columns = features[1]

# %%
importance= rf.feature_importances_

# %%
feature_importance = pd.DataFrame({
    'feature': x_train.columns,
    'importance': importance
})

# %%
feature_importance= feature_importance.sort_values(
    "importance",
    ascending= False
)

# %%
feature_importance.head()
# Out:
#                     feature  importance
# 52      tGravityAcc-min()-X    0.036171
# 559    angle(Y,gravityMean)    0.027985
# 50      tGravityAcc-max()-Y    0.027514
# 49      tGravityAcc-max()-X    0.027397
# 56   tGravityAcc-energy()-X    0.026916
